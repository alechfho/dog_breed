# %%
import numpy as np 
import pandas as pd
import math as math
import random
import time

from triplet_encoding import *
from shared_module import *

from triplet_encoding import *
# Out:
# Using TensorFlow backend.

# %%
N_ANCHORS = ANCHORS_12
ENCODING_STRATEGY = VGG19_4096
ENCODING_SIZE = 4096

INPUT_FILE_PATH = './input/labels'

labels_file_path = get_path(INPUT_FILE_PATH, N_ANCHORS, ENCODING_STRATEGY)

df_labels = pd.read_csv(labels_file_path('anchor'))

display(df_labels.head())
# Out:
#                                  id             breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever
#
#                                             encoding anp  cluster
# 0  ./input/vgg19_4096/000bec180eb18c7604dcecc8fe0...   P        6
# 1  ./input/vgg19_4096/001513dfcb2ffafc82cccf4d8bb...   P        5
# 2  ./input/vgg19_4096/001cdf01b096e06d78e9e5112d4...   P        6
# 3  ./input/vgg19_4096/00214f311d5d2247d5dfe4fe24b...   P        1
# 4  ./input/vgg19_4096/0021f9ceb3235effd7fcde7f753...   P        4

# %%
breeds = df_labels['breed'].unique()
breeds.sort()
print(breeds)
# Out:
# ['affenpinscher' 'afghan_hound' 'african_hunting_dog' 'airedale'
#  'american_staffordshire_terrier' 'appenzeller' 'australian_terrier'
#  'basenji' 'basset' 'beagle' 'bedlington_terrier' 'bernese_mountain_dog'
#  'black-and-tan_coonhound' 'blenheim_spaniel' 'bloodhound' 'bluetick'
#  'border_collie' 'border_terrier' 'borzoi' 'boston_bull'
#  'bouvier_des_flandres' 'boxer' 'brabancon_griffon' 'briard'
#  'brittany_spaniel' 'bull_mastiff' 'cairn' 'cardigan'
#  'chesapeake_bay_retriever' 'chihuahua' 'chow' 'clumber' 'cocker_spaniel'
#  'collie' 'curly-coated_retriever' 'dandie_dinmont' 'dhole' 'dingo'
#  'doberman' 'english_foxhound' 'english_setter' 'english_springer'
#  'entlebucher' 'eskimo_dog' 'flat-coated_retriever' 'french_bulldog'
#  'german_shepherd' 'german_short-haired_pointer' 'giant_schnauzer'
#  'golden_retriever' 'gordon_setter' 'great_dane' 'great_pyrenees'
#  'greater_swiss_mountain_dog' 'groenendael' 'ibizan_hound' 'irish_setter'
# ...

# %%
df_test = pd.read_csv('input/labels_test_vgg19_4096.csv')
display(df_test.head())
# Out:
#    Unnamed: 0                                id  \
# 0           0  266490a2b053a4a3bf68e779f28fb5a9
# 1           1  dae9fd18836d8df20989ef0101771d4b
# 2           2  079a40f22b0fad9a66f76797b62bb930
# 3           3  ab8462f9a501d362041d47582fddc9ad
# 4           4  8895089b432e020cc42e6262b5a1c2dd
#
#                                             encoding
# 0  input/test-2//vgg19_4096/266490a2b053a4a3bf68e...
# 1  input/test-2//vgg19_4096/dae9fd18836d8df20989e...
# 2  input/test-2//vgg19_4096/079a40f22b0fad9a66f76...
# 3  input/test-2//vgg19_4096/ab8462f9a501d362041d4...
# 4  input/test-2//vgg19_4096/8895089b432e020cc42e6...

# %%
encoding_model = input_encoding_model((1, ENCODING_SIZE))
predictions = predict_on_test_model(df_labels, df_test, breeds, model_encode(encoding_model, ENCODING_SIZE))

# %%
cols = ['id']
cols.extend(breeds)
pd.DataFrame(predictions, columns=cols)
# Out:
#                                      id  affenpinscher  afghan_hound  \
# 0      266490a2b053a4a3bf68e779f28fb5a9       0.184060      0.174765
# 1      dae9fd18836d8df20989ef0101771d4b       0.142118      0.118433
# 2      079a40f22b0fad9a66f76797b62bb930       0.128717      0.164842
# 3      ab8462f9a501d362041d47582fddc9ad       0.122493      0.130282
# 4      8895089b432e020cc42e6262b5a1c2dd       0.201589      0.163448
# 5      985ae7fc271ac4a0d131e546c0f95bb6       0.188014      0.196052
# 6      77c1ab99cffb817d54fb14f229aeb118       0.145582      0.132895
# 7      ad7e50abca9b7c6a88b63946c5bbe493       0.156613      0.123973
# 8      d61a09cecf56666cdb315ebce4b93c43       0.141138      0.125510
# 9      cb120c57904e8c0694bbe259c58a873c       0.118052      0.131654
# 10     10863e6d9d1cb526cc9d90f30a585719       0.101255      0.128529
# 11     43cb5f3a505d710bd16e0a0d583a781b       0.123370      0.089807
# 12     a5aa4e972242a61829ad10b220a12c64       0.154982      0.131459
# ...
